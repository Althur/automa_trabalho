# %%
import os
import sys 
import tabula

import numpy as np
import pandas as pd

"""
sys.path.append('.')
sys.path.append('./Functions')
from fetch_data import *
"""



from xlrd import open_workbook
from pdfminer.high_level import extract_text
from PyPDF2 import PdfFileReader

# %%
# path_cru = C:\Users\ForpusCapital\Box\FORPUS\Operacional\Carteiras\2015-2020\2020\12-2020\31-12-2020
path = "C:\\Users\\ForpusCapital\\Box\\FORPUS\\Operacional\\Carteiras\\2015-2020\\2020\\12-2020\\31-12-2020\\"
f_nome_do_fundo = ""
forpus_70_prev = "FORPUS 70 PREV_20201231.pdf"
forpus_100_icatu = "FORPUS 100 ICAT_20201231.pdf"
forpus_prev_master = "FORPUS 100 MAST_20201231.pdf"
forpus_acoes_master = "FORPUS ACOES_20201231.pdf"
forpus_equities = "FORPUS EQ CL_20201231.pdf"
forpus_koi = "FORPUS KOI_20201231.pdf"
forpus_multi = "FORPUS MULTI_20201231.pdf"

# path_master_pdf = os.path.join(final_path, folhinha_master_pdf) 
prev_70 = os.path.join(path, forpus_70_prev)
prev_100_icatu = path+forpus_100_icatu
prev_master = path+forpus_prev_master
acoes_master = path+forpus_acoes_master
equities = path +forpus_equities
koi = path+forpus_koi
multi = path+forpus_multi

# %%
df = tabula.read_pdf(multi, pages = "all")

# %%
df[0]
# Out:
#                          Cliente Data da Posição  Unnamed: 0 Cota Liberada  \
# 0  FORPUS MULTIESTRATEGIA FIM LP      31/12/2020         NaN           Não
#
#   Tipo da Posição Moeda  Cotação
# 0               F  REAL      NaN

# %%
df[1]#["Renda Variável"]
# Out:
#                  Renda Variável             Unnamed: 0       Unnamed: 1  \
# 0                          Ação                    NaN              NaN
# 1                        Código                  Papel  Qtd. Disponível
# 2                       BOVESPA                    NaN              NaN
# 3                         AVLL3                     ON                0
# 4                        BIDI11     BANCO INTER SA PNE            1,400
# 5                        BPAC11         BTGP BANCO PNE            3,400
# 6                         CASH3                CASH ON           20,000
# 7                        IVVB11       ISHARE SP500 PNE              600
# 8                         JHSF3         JHSF PARTON NM           80,000
# 9                         LWSA3                     ON            5,800
# 10                        MGLU3    MAGAZINE LUIZA S.A.           14,000
# 11                        NTCO3  NATURA COSMETICOS S/A            6,000
# 12                        SEQL3                     ON           12,000
# 13                        TOTS3             TOTVSON NM           18,000
# 14                        WEGE3               WEGON NM            4,000
# 15                        Total                165,200            7,000
# 16                  Total Geral                165,200            7,000
# 17          Empréstimo de Ações                    NaN              NaN
# 18                          NaN                    NaN              NaN
# 19                Cód. Operação          Data Operação     Data Vencto.
# 20  BOVESPA - Operação Tomadora                    NaN              NaN
# 21                     16844782             15/12/2020       29/01/2021
# 22                     16865820             21/12/2020       04/02/2021
# 23                     16881719             18/12/2020       05/02/2021
# 24                     16874679             22/12/2020       05/02/2021
# 25                     16894137             28/12/2020       09/02/2021
# 26                     16894138             28/12/2020       09/02/2021
# 27                     16894139             28/12/2020       09/02/2021
# 28                        Total                    NaN       660,618.00
# 29                  Total Geral                    NaN       660,618.00
#
#         Unnamed: 2        Unnamed: 3                 Unnamed: 4    Unnamed: 5  \
# 0              NaN               NaN                        NaN           NaN
# 1   Qtd. Bloqueada        Qtd. Total  Custo Médio c/ corretagem       Cotação
# 2              NaN               NaN                        NaN           NaN
# 3            4,000             4,000                      23.61         23.60
# 4            1,400             2,800                      93.16         98.45
# 5              400             3,800                      92.77         94.00
# 6                0            20,000                      15.17         15.01
# 7                0               600                     209.60        210.04
# 8                0            80,000                       7.67          7.81
# 9            1,200             7,000                      68.73         80.47
# 10               0            14,000                      24.18         24.95
# 11               0             6,000                      49.28         52.50
# 12               0            12,000                      22.30         22.79
# 13               0            18,000                      26.97         28.72
# 14               0             4,000                      73.65         75.74
# 15         172,200               NaN               3,913,632.09    185,641.91
# 16         172,200               NaN                        NaN  3,913,632.09
# 17             NaN               NaN                        NaN           NaN
# 18             NaN               NaN                        NaN           NaN
# 19          Código             Papel                       Qtd.         Preço
# 20             NaN               NaN                        NaN           NaN
# 21          IVVB11  ISHARE SP500 PNE                        200        202.38
# 22          IVVB11  ISHARE SP500 PNE                        200        203.73
# 23          IVVB11  ISHARE SP500 PNE                        200        203.54
# 24          IVVB11  ISHARE SP500 PNE                        200        204.40
# 25          IVVB11  ISHARE SP500 PNE                      1,190        207.42
# 26          IVVB11  ISHARE SP500 PNE                      1,153        207.42
# 27          IVVB11  ISHARE SP500 PNE                         57        207.42
# 28             NaN          (215.82)                    (65.37)      (281.19)
# 29             NaN               NaN                   (215.82)       (65.37)
#
#       Unnamed: 6    Unnamed: 7              Unnamed: 8    Unnamed: 9  \
# 0            NaN           NaN                     NaN           NaN
# 1    Custo Total     Resultado  Valor de Mercado Bruto          IRRF
# 2            NaN           NaN                     NaN           NaN
# 3      94,426.50       (26.50)               94,400.00          0.00
# 4     260,855.27     14,804.73              275,660.00          0.00
# 5     352,521.84      4,678.16              357,200.00          0.00
# 6     303,362.13    (3,162.13)              300,200.00          0.00
# 7     125,762.25        261.75              126,024.00          0.00
# 8     613,812.85     10,987.15              624,800.00          0.00
# 9     481,110.34     82,179.66              563,290.00          0.00
# 10    338,460.36     10,839.64              349,300.00          0.00
# 11    295,651.55     19,348.45              315,000.00          0.00
# 12    267,619.13      5,860.87              273,480.00          0.00
# 13    485,461.16     31,498.84              516,960.00          0.00
# 14    294,588.71      8,371.29              302,960.00          0.00
# 15  4,099,274.00          0.00            4,099,274.00       100.00%
# 16    185,641.91  4,099,274.00                    0.00  4,099,274.00
# 17           NaN           NaN                     NaN           NaN
# 18           NaN           NaN                     NaN           NaN
# 19           NaN    Financeiro             % S/ Remun.  % S/ Mercado
# 20           NaN           NaN                     NaN           NaN
# 21           NaN     40,476.00                   3.00%         0.00%
# 22           NaN     40,746.00                   2.75%         0.00%
# 23           NaN     40,708.00                   2.75%         0.00%
# 24           NaN     40,880.00                   2.76%         0.00%
# 25           NaN    246,829.80                   2.75%         0.00%
# 26           NaN    239,155.26                   2.75%         0.00%
# 27           NaN     11,822.94                   2.75%         0.00%
# 28       100.00%         1.89%                     NaN           NaN
# 29      (281.19)       100.00%                   1.89%           NaN
#
#                  Unnamed: 10 Unnamed: 11 Unnamed: 12      Unnamed: 13  \
# 0                        NaN         NaN         NaN              NaN
# 1   Valor de Mercado Líquido   % S/ Ação  % S/ Total              NaN
# 2                        NaN         NaN         NaN              NaN
# 3                  94,400.00       2.30%       0.27%              NaN
# 4                 275,660.00       6.72%       0.79%              NaN
# 5                 357,200.00       8.71%       1.02%              NaN
# 6                 300,200.00       7.32%       0.86%              NaN
# 7                 126,024.00       3.07%       0.36%              NaN
# 8                 624,800.00      15.24%       1.79%              NaN
# 9                 563,290.00      13.74%       1.61%              NaN
# 10                349,300.00       8.52%       1.00%              NaN
# 11                315,000.00       7.68%       0.90%              NaN
# 12                273,480.00       6.67%       0.78%              NaN
# 13                516,960.00      12.61%       1.48%              NaN
# 14                302,960.00       7.39%       0.87%              NaN
# 15                    11.74%         NaN         NaN              NaN
# 16                   100.00%      11.74%         NaN              NaN
# 17                       NaN         NaN         NaN              NaN
# 18                       NaN         NaN         NaN              NaN
# 19                    Remun.       Taxas       Total  % S/ Empréstimo
# 20                       NaN         NaN         NaN              NaN
# 21                   (42.75)     (12.95)     (55.70)            6.13%
# 22                   (21.93)      (6.64)     (28.57)            6.17%
# 23                   (26.30)      (7.96)     (34.26)            6.16%
# 24                   (17.67)      (5.35)     (23.02)            6.19%
# 25                   (53.14)     (16.10)     (69.24)           37.36%
# 26                   (51.49)     (15.60)     (67.09)           36.20%
# 27                    (2.54)      (0.77)      (3.31)            1.79%
# 28                       NaN         NaN         NaN              NaN
# 29                       NaN         NaN         NaN              NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19  % S/ Total
# 20         NaN
# 21       0.12%
# 22       0.12%
# 23       0.12%
# 24       0.12%
# 25       0.71%
# 26       0.68%
# 27       0.03%
# 28         NaN
# 29         NaN

# %%
df[2]
# Out:
#     Futuro Unnamed: 0            Unnamed: 1 Unnamed: 2          Unnamed: 3  \
# 0    Ativo    Vencto.             Corretora       Qtd.  Ajuste Equalização
# 1      BMF        NaN                   NaN        NaN                 NaN
# 2  FUT DI1        F22  NOVA FUTURA DTVM LTD       (60)                0.00
#
#            Unnamed: 4        Unnamed: 5        Unnamed: 6   Unnamed: 7  \
# 0  Ajuste Valorização  Preço de Mercado  Valor de Mercado  % S/ Futuro
# 1                 NaN               NaN               NaN          NaN
# 2                0.00         97,208.64    (5,832,518.40)       93.37%
#
#    Unnamed: 8
# 0  % S/ Total
# 1         NaN
# 2    (16.70)%

# %%
df[3]
# Out:
#                        Futuro            Unnamed: 0            Unnamed: 1  \
# 0                       Ativo               Vencto.             Corretora
# 1                     FUT WDO                   G21  NOVA FUTURA DTVM LTD
# 2                       Total                  0.00                  0.00
# 3                 Total Geral                  0.00                  0.00
# 4             Opção de Futuro                   NaN                   NaN
# 5                      Código                   NaN               Vencto.
# 6                         BMF                   NaN                   NaN
# 7                     OPD DOL                   NaN                  FPD1
# 8                     OPD DOL                   NaN                  GPDQ
# 9                     OPD DOL                   NaN                  GPDN
# 10                      Total             86,899.85             21,766.21
# 11                Total Geral             86,899.85             21,766.21
# 12                      Fundo                   NaN                   NaN
# 13                     Código                 Fundo                  CNPJ
# 14  Investimentos no Exterior                   NaN                   NaN
# 15                   HASHDEXD  HASHDEX DIG ASSET IN    00.000.000/0000-00
# 16                      Total          370.11810000                   NaN
# 17                 Renda Fixa                   NaN                   NaN
# 18                      MBLIQ   BNYM ARX LIQ FI REF    17.898.543/0001-70
# 19                    MBLIQII    BNYM ARX LIQREF II    18.416.618/0001-00
# 20                   MBLIQIII   BNYM ARX LIQREF III    18.416.553/0001-95
# 21                    MBLIQIV    BNYM ARX LIQREF IV    18.418.812/0001-17
# 22                    MBLIQIX    BNYM ARX LIQREF IX    18.418.915/0001-87
# 23                     MBLIQV     BNYM ARX LIQREF V    18.418.851/0001-14
# 24                    MBLIQVI    BNYM ARX LIQREF VI    18.418.825/0001-96
# 25                   MBLIQVII   BNYM ARX LIQREF VII    18.428.603/0001-54
# 26                   MBLQVIII  BNYM ARX LIQREF VIII    18.418.874/0001-29
# 27                     MBLIQX     BNYM ARX LIQREF X    18.418.894/0001-08
# 28                      Total    4,012,776.78642440                   NaN
# 29             Renda Variável                   NaN                   NaN
# 30                   FORPACMA     FORPUS ACOES MAST    21.917.206/0001-50
# 31                      Total    1,005,213.02053853                   NaN
# 32                Total Geral    5,018,359.92506293                   NaN
# 33                 Renda Fixa                   NaN                   NaN
# 34                     Código             Aquisição              Emitente
# 35                       CBIO                   NaN                   NaN
# 36                    C270617            11/11/2020                  NOFU
# 37                    C272729            13/11/2020                  NOFU
# 38                    C272725            13/11/2020                  NOFU
# 39                    C284378            30/11/2020                  NOFU
# 40                    C284432            30/11/2020                  NOFU
# 41                    C284725            30/11/2020                  NOFU
# 42                    C284724            30/11/2020                  NOFU
# 43                    C284755            30/11/2020                  NOFU
# 44                    C300205            18/12/2020                  NOFU
# 45                    C281052            25/11/2020                  NOFU
#
#       Unnamed: 2                           Unnamed: 3          Unnamed: 4  \
# 0           Qtd.                   Ajuste Equalização  Ajuste Valorização
# 1            (8)                                 0.00                0.00
# 2            NaN                       (6,246,894.40)             100.00%
# 3            NaN                       (6,246,894.40)             100.00%
# 4            NaN                                  NaN                 NaN
# 5           Tipo                                Papel           Corretora
# 6            NaN                                  NaN                 NaN
# 7            PUT  Opção s/disp. / Dólar comercia FPD1            NOVA FUT
# 8            PUT  Opção s/disp. / Dólar comercia GPDQ            NOVA FUT
# 9            PUT  Opção s/disp. / Dólar comercia GPDN            NOVA FUT
# 10    108,666.06                              100.00%               0.31%
# 11    108,666.06                              100.00%               0.31%
# 12           NaN                                  NaN                 NaN
# 13   Instituição                        Qtd. de Cotas      Qtd. Bloqueada
# 14           NaN                                  NaN                 NaN
# 15          AISB                         370.11810000          0.00000000
# 16  5,939,753.99                                 0.00        5,939,753.99
# 17           NaN                                  NaN                 NaN
# 18      MSF DTVM                     393,294.17281054          0.00000000
# 19      MSF DTVM                     400,094.47088605          0.00000000
# 20      MSF DTVM                     400,022.14204481          0.00000000
# 21      MSF DTVM                     400,013.49488243          0.00000000
# 22      MSF DTVM                     405,204.11764854          0.00000000
# 23      MSF DTVM                     401,254.41006735          0.00000000
# 24      MSF DTVM                     401,265.55330637          0.00000000
# 25      MSF DTVM                     401,271.69695526          0.00000000
# 26      MSF DTVM                     405,145.24445390          0.00000000
# 27      MSF DTVM                     405,211.48336915          0.00000000
# 28  7,184,660.89                                 0.00        7,184,660.89
# 29           NaN                                  NaN                 NaN
# 30      MSF DTVM                   1,005,213.02053853          0.00000000
# 31  8,549,106.95                                 0.00        8,549,106.95
# 32           NaN                                  NaN       21,673,521.83
# 33           NaN                                  NaN                 NaN
# 34         Ativo                              MTM %aa             Tx Over
# 35           NaN                                  NaN                 NaN
# 36       1961314                            0.000000%           0.000000%
# 37       1962883                            0.000000%           0.000000%
# 38       1962884                            0.000000%           0.000000%
# 39       1971761                            0.000000%           0.000000%
# 40       1971797                            0.000000%           0.000000%
# 41       1971892                            0.000000%           0.000000%
# 42       1971891                            0.000000%           0.000000%
# 43       1971939                            0.006977%           0.000000%
# 44       1984184                            0.002067%           0.000000%
# 45       1969133                            0.008269%           0.000000%
#
#           Unnamed: 5        Unnamed: 6    Unnamed: 7  \
# 0   Preço de Mercado  Valor de Mercado   % S/ Futuro
# 1           5,179.70      (414,376.00)         6.63%
# 2           (17.88)%               NaN           NaN
# 3           (17.88)%               NaN           NaN
# 4                NaN               NaN           NaN
# 5          Exercício      Data Vencto.          Qtd.
# 6                NaN               NaN           NaN
# 7           5,000.00        04/01/2021         10.00
# 8           5,000.00        01/02/2021         10.00
# 9           4,900.00        01/02/2021         60.00
# 10               NaN               NaN           NaN
# 11               NaN               NaN           NaN
# 12               NaN               NaN           NaN
# 13     Valor da Cota    Aplic. / Resg.   Valor Atual
# 14               NaN               NaN           NaN
# 15   16,048.26672852              0.00  5,939,753.99
# 16            27.41%            17.01%           NaN
# 17               NaN               NaN           NaN
# 18        1.82458978              0.00    717,600.53
# 19        1.79564273              0.00    718,426.73
# 20        1.79636323              0.00    718,585.07
# 21        1.79639377              0.00    718,581.75
# 22        1.77329834              0.00    718,547.79
# 23        1.79084259              0.00    718,583.49
# 24        1.79075474              0.00    718,568.19
# 25        1.79075891              0.00    718,580.87
# 26        1.77374590              0.00    718,624.72
# 27        1.77330061              0.00    718,561.77
# 28            33.15%            20.57%           NaN
# 29               NaN               NaN           NaN
# 30        8.50477140              0.00  8,549,106.95
# 31            39.44%            24.48%           NaN
# 32              0.00     21,673,521.83       100.00%
# 33               NaN               NaN           NaN
# 34             Tx%aa            Index.       Emissão
# 35               NaN               NaN           NaN
# 36         0.000000%               PRE    11/11/2020
# 37         0.000000%               PRE    16/07/2020
# 38         0.000000%               PRE    03/08/2020
# 39         0.000000%               PRE    26/10/2020
# 40         0.000000%               PRE    03/11/2020
# 41         0.000000%               PRE    11/11/2020
# 42         0.000000%               PRE    16/11/2020
# 43         0.001288%             SELIC    23/11/2020
# 44         0.000000%             SELIC    18/12/2020
# 45         0.001803%             SELIC    16/11/2020
#
#                    Unnamed: 8     Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0                  % S/ Total            NaN          NaN          NaN
# 1                     (1.19)%            NaN          NaN          NaN
# 2                         NaN            NaN          NaN          NaN
# 3                         NaN            NaN          NaN          NaN
# 4                         NaN            NaN          NaN          NaN
# 5   Custo Médio c/ corretagem        Cotação  Custo Total    Resultado
# 6                         NaN            NaN          NaN          NaN
# 7                       21.02           0.04    10,509.67  (10,490.01)
# 8                       61.02          51.72    30,509.67   (4,647.20)
# 9                       15.29          27.59    45,880.51    36,903.42
# 10                        NaN            NaN          NaN          NaN
# 11                        NaN            NaN          NaN          NaN
# 12                        NaN            NaN          NaN          NaN
# 13                       Imp.  Valor Líquido   % S/ Fundo   % S/ Total
# 14                        NaN            NaN          NaN          NaN
# 15                       0.00   5,939,753.99       27.41%       17.01%
# 16                        NaN            NaN          NaN          NaN
# 17                        NaN            NaN          NaN          NaN
# 18                       0.00     717,600.53        3.31%        2.05%
# 19                       0.00     718,426.73        3.31%        2.06%
# 20                       0.00     718,585.07        3.32%        2.06%
# 21                       0.00     718,581.75        3.32%        2.06%
# 22                       0.00     718,547.79        3.32%        2.06%
# 23                       0.00     718,583.49        3.32%        2.06%
# 24                       0.00     718,568.19        3.32%        2.06%
# 25                       0.00     718,580.87        3.32%        2.06%
# 26                       0.00     718,624.72        3.32%        2.06%
# 27                       0.00     718,561.77        3.32%        2.06%
# 28                        NaN            NaN          NaN          NaN
# 29                        NaN            NaN          NaN          NaN
# 30                       0.00   8,549,106.95       39.44%       24.48%
# 31                        NaN            NaN          NaN          NaN
# 32                     62.05%            NaN          NaN          NaN
# 33                        NaN            NaN          NaN          NaN
# 34                    Vencto.            NaN         Qtd.           PU
# 35                        NaN            NaN          NaN          NaN
# 36                 31/12/2049            NaN       5.0000  36.00000000
# 37                 31/12/2049            NaN     995.0000  40.50000000
# 38                 31/12/2049            NaN   1,000.0000  40.50000000
# 39                 31/12/2049            NaN   4,210.0000  40.00000000
# 40                 31/12/2049            NaN     790.0000  40.00000000
# 41                 31/12/2049            NaN     110.0000  39.99000000
# 42                 31/12/2049            NaN     737.0000  39.99000000
# 43                 31/12/2049            NaN     153.0000  39.99000000
# 44                 31/12/2049            NaN   2,000.0000  33.50000000
# 45                 31/12/2049            NaN   2,000.0000  40.10000000
#
#          Unnamed: 12           Unnamed: 13  Unnamed: 14 Unnamed: 15  \
# 0                NaN                   NaN          NaN         NaN
# 1                NaN                   NaN          NaN         NaN
# 2                NaN                   NaN          NaN         NaN
# 3                NaN                   NaN          NaN         NaN
# 4                NaN                   NaN          NaN         NaN
# 5   Valor de Mercado  % S/ Opção de Futuro   % S/ Total         NaN
# 6                NaN                   NaN          NaN         NaN
# 7              19.66                 0.02%        0.00%         NaN
# 8          25,862.47                23.80%        0.07%         NaN
# 9          82,783.93                76.18%        0.24%         NaN
# 10               NaN                   NaN          NaN         NaN
# 11               NaN                   NaN          NaN         NaN
# 12               NaN                   NaN          NaN         NaN
# 13               NaN                   NaN          NaN         NaN
# 14               NaN                   NaN          NaN         NaN
# 15               NaN                   NaN          NaN         NaN
# 16               NaN                   NaN          NaN         NaN
# 17               NaN                   NaN          NaN         NaN
# 18               NaN                   NaN          NaN         NaN
# 19               NaN                   NaN          NaN         NaN
# 20               NaN                   NaN          NaN         NaN
# 21               NaN                   NaN          NaN         NaN
# 22               NaN                   NaN          NaN         NaN
# 23               NaN                   NaN          NaN         NaN
# 24               NaN                   NaN          NaN         NaN
# 25               NaN                   NaN          NaN         NaN
# 26               NaN                   NaN          NaN         NaN
# 27               NaN                   NaN          NaN         NaN
# 28               NaN                   NaN          NaN         NaN
# 29               NaN                   NaN          NaN         NaN
# 30               NaN                   NaN          NaN         NaN
# 31               NaN                   NaN          NaN         NaN
# 32               NaN                   NaN          NaN         NaN
# 33               NaN                   NaN          NaN         NaN
# 34   Valor Aplicação         Valor Resgate  Valor Bruto        Imp.
# 35               NaN                   NaN          NaN         NaN
# 36            180.00                  0.00       180.00        0.00
# 37         40,297.50                  0.00    40,297.50        0.00
# 38         40,500.00                  0.00    40,500.00        0.00
# 39        168,400.00                  0.00   168,400.00        0.00
# 40         31,600.00                  0.00    31,600.00        0.00
# 41          4,398.90                  0.00     4,398.90        0.00
# 42         29,472.63                  0.00    29,472.63        0.00
# 43          6,118.47                  0.00     6,118.47        0.00
# 44         67,000.00                  0.00    67,000.00        0.00
# 45         80,200.00                  0.00    80,200.00        0.00
#
#       Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# 5             NaN         NaN         NaN
# 6             NaN         NaN         NaN
# 7             NaN         NaN         NaN
# 8             NaN         NaN         NaN
# 9             NaN         NaN         NaN
# 10            NaN         NaN         NaN
# 11            NaN         NaN         NaN
# 12            NaN         NaN         NaN
# 13            NaN         NaN         NaN
# 14            NaN         NaN         NaN
# 15            NaN         NaN         NaN
# 16            NaN         NaN         NaN
# 17            NaN         NaN         NaN
# 18            NaN         NaN         NaN
# 19            NaN         NaN         NaN
# 20            NaN         NaN         NaN
# 21            NaN         NaN         NaN
# 22            NaN         NaN         NaN
# 23            NaN         NaN         NaN
# 24            NaN         NaN         NaN
# 25            NaN         NaN         NaN
# 26            NaN         NaN         NaN
# 27            NaN         NaN         NaN
# 28            NaN         NaN         NaN
# 29            NaN         NaN         NaN
# 30            NaN         NaN         NaN
# 31            NaN         NaN         NaN
# 32            NaN         NaN         NaN
# 33            NaN         NaN         NaN
# 34  Valor Líquido     % S/ RF  % S/ Total
# 35            NaN         NaN         NaN
# 36         180.00       0.00%       0.00%
# 37      40,297.50       0.35%       0.12%
# 38      40,500.00       0.36%       0.12%
# 39     168,400.00       1.48%       0.48%
# 40      31,600.00       0.28%       0.09%
# 41       4,398.90       0.04%       0.01%
# 42      29,472.63       0.26%       0.08%
# 43       6,118.47       0.05%       0.02%
# 44      67,000.00       0.59%       0.19%
# 45      80,200.00       0.71%       0.23%

# %%
df[4]
# Out:
#                                  Renda Fixa  \
# 0                                    Código
# 1                                     Total
# 2                                      NTNB
# 3                                  C261804A
# 4                                     Total
# 5                                     NTN-F
# 6                                   C254359
# 7                                   C275705
# 8                                  C286716A
# 9                                     Total
# 10                              Total Geral
# 11                   Contas a Pagar/Receber
# 12                   Contas a Pagar/Receber
# 13                        Ajuste de Futuros
# 14                        Ajuste de Futuros
# 15                        Ajuste de Futuros
# 16                                    Total
# 17                Ajuste de Liquidação BM&F
# 18                Ajuste de Liquidação BM&F
# 19                                    Total
# 20                                Bancárias
# 21                                Bancárias
# 22                                    Total
# 23           Corretagens e Emolumentos BM&F
# 24           Corretagens e Emolumentos BM&F
# 25           Corretagens e Emolumentos BM&F
# 26                                    Total
# 27                         Cotas a Resgatar
# 28                         Cotas a Resgatar
# 29                                    Total
# 30              Empréstimo de Ações a Pagar
# 31              Empréstimo de Ações a Pagar
# 32              Empréstimo de Ações a Pagar
# 33              Empréstimo de Ações a Pagar
# 34              Empréstimo de Ações a Pagar
# 35              Empréstimo de Ações a Pagar
# 36              Empréstimo de Ações a Pagar
# 37              Empréstimo de Ações a Pagar
# 38                                    Total
# 39                        Fatura da BOVESPA
# 40                        Fatura da BOVESPA
# 41                        Fatura da BOVESPA
# 42                                    Total
# 43  Fatura de Empréstimo de Ações - Tomador
# 44  Fatura de Empréstimo de Ações - Tomador
#
#                                            Unnamed: 0    Unnamed: 1  \
# 0                                           Aquisição      Emitente
# 1                                         12,000.0000           NaN
# 2                                                 NaN           NaN
# 3                                          30/10/2020       TESOURO
# 4                                            800.0000           NaN
# 5                                                 NaN           NaN
# 6                                          21/10/2020       TESOURO
# 7                                          18/11/2020       TESOURO
# 8                                          03/12/2020       TESOURO
# 9                                          6,200.0000           NaN
# 10                                        19,000.0000           NaN
# 11                                                NaN           NaN
# 12                             Contas a Pagar/Receber         Valor
# 13                                                NaN           NaN
# 14                           Ajuste Credor de Futuros      4,024.00
# 15                          Ajuste Devedor de Futuros    (1,360.20)
# 16                                           2,663.80       (0.11)%
# 17                                                NaN           NaN
# 18    CORRETAGEM FUTUROS FUT WDO 30/12 em: 04/01/2021        (8.34)
# 19                                             (8.34)         0.00%
# 20                                                NaN           NaN
# 21  Despesa de Tarifa de Liquidação Financeira com...      (366.96)
# 22                                           (366.96)         0.02%
# 23                                                NaN           NaN
# 24  Taxa de Futuros/Opções [FUT WDO]/[G21]/[NOVA F...       (14.52)
# 25  Corretagem de Futuros/Opções [FUT WDO]/[G21]/[...        (3.26)
# 26                                            (17.78)         0.00%
# 27                                                NaN           NaN
# 28                                   Cotas a Resgatar  (540,917.85)
# 29                                       (540,917.85)        23.33%
# 30                                                NaN           NaN
# 31  Empr. de Ações a pagar para o papel IVVB11 na ...   (42,008.00)
# 32  Empr. de Ações a pagar para o papel IVVB11 na ...  (249,947.60)
# 33  Empr. de Ações a pagar para o papel IVVB11 na ...  (242,176.12)
# 34  Empr. de Ações a pagar para o papel IVVB11 na ...   (11,972.28)
# 35  Empr. de Ações a pagar para o papel IVVB11 na ...   (42,008.00)
# 36  Empr. de Ações a pagar para o papel IVVB11 na ...   (42,008.00)
# 37  Empr. de Ações a pagar para o papel IVVB11 na ...   (42,008.00)
# 38                                       (672,128.00)        28.99%
# 39                                                NaN           NaN
# 40                               Venda de Ações [D+1]      2,240.58
# 41                              Compra de Ações [D+2]  (127,863.60)
# 42                                       (125,623.02)         5.42%
# 43                                                NaN           NaN
# 44  Fatura de Empr. de Ações Tomadora do papel [IV...       (32.95)
#
#         Unnamed: 2   Unnamed: 3     Unnamed: 4   Unnamed: 5     Unnamed: 6  \
# 0            Ativo      MTM %aa        Tx Over        Tx%aa         Index.
# 1       468,167.50         0.00     468,167.50         0.00     468,167.50
# 2              NaN          NaN            NaN          NaN            NaN
# 3           736585    0.003438%      1.718690%    0.184296%          IPC-A
# 4     2,991,406.75         0.00   3,058,929.55         0.00   3,058,929.55
# 5              NaN          NaN            NaN          NaN            NaN
# 6          1802755  (2.325202)%      0.794435%  (1.667726)%            PRE
# 7          1802755  (2.325202)%      0.794435%  (1.662211)%            PRE
# 8          1802755  (2.325202)%      0.794435%  (1.840043)%            PRE
# 9     7,372,114.65         0.00   7,838,664.96         0.00   7,838,664.96
# 10   10,831,688.90         0.00  11,365,762.01         0.00  11,365,762.01
# 11             NaN          NaN            NaN          NaN            NaN
# 12  % S/ Total CPR   % S/ Total            NaN          NaN            NaN
# 13             NaN          NaN            NaN          NaN            NaN
# 14         (0.17)%        0.01%            NaN          NaN            NaN
# 15           0.06%      (0.00)%            NaN          NaN            NaN
# 16           0.01%          NaN            NaN          NaN            NaN
# 17             NaN          NaN            NaN          NaN            NaN
# 18           0.00%      (0.00)%            NaN          NaN            NaN
# 19         (0.00)%          NaN            NaN          NaN            NaN
# 20             NaN          NaN            NaN          NaN            NaN
# 21           0.02%      (0.00)%            NaN          NaN            NaN
# 22         (0.00)%          NaN            NaN          NaN            NaN
# 23             NaN          NaN            NaN          NaN            NaN
# 24           0.00%      (0.00)%            NaN          NaN            NaN
# 25           0.00%      (0.00)%            NaN          NaN            NaN
# 26         (0.00)%          NaN            NaN          NaN            NaN
# 27             NaN          NaN            NaN          NaN            NaN
# 28          23.33%      (1.55)%            NaN          NaN            NaN
# 29         (1.55)%          NaN            NaN          NaN            NaN
# 30             NaN          NaN            NaN          NaN            NaN
# 31           1.81%      (0.12)%            NaN          NaN            NaN
# 32          10.78%      (0.72)%            NaN          NaN            NaN
# 33          10.45%      (0.69)%            NaN          NaN            NaN
# 34           0.52%      (0.03)%            NaN          NaN            NaN
# 35           1.81%      (0.12)%            NaN          NaN            NaN
# 36           1.81%      (0.12)%            NaN          NaN            NaN
# 37           1.81%      (0.12)%            NaN          NaN            NaN
# 38         (1.92)%          NaN            NaN          NaN            NaN
# 39             NaN          NaN            NaN          NaN            NaN
# 40         (0.10)%        0.01%            NaN          NaN            NaN
# 41           5.52%      (0.37)%            NaN          NaN            NaN
# 42         (0.36)%          NaN            NaN          NaN            NaN
# 43             NaN          NaN            NaN          NaN            NaN
# 44           0.00%      (0.00)%            NaN          NaN            NaN
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9     Unnamed: 10      Unnamed: 11  \
# 0      Emissão     Vencto.        Qtd.              PU  Valor Aplicação
# 1        4.12%       1.34%         NaN             NaN              NaN
# 2          NaN         NaN         NaN             NaN              NaN
# 3   15/02/2012  15/08/2022    800.0000  3,823.66193600     2,991,406.75
# 4       26.91%       8.76%         NaN             NaN              NaN
# 5          NaN         NaN         NaN             NaN              NaN
# 6   27/01/2020  01/01/2031  4,200.0000  1,264.30080100     4,982,838.59
# 7   27/01/2020  01/01/2031  1,000.0000  1,264.30080100     1,184,216.59
# 8   27/01/2020  01/01/2031  1,000.0000  1,264.30080100     1,205,059.47
# 9       68.96%      22.44%         NaN             NaN              NaN
# 10      99.99%      32.54%         NaN             NaN              NaN
# 11         NaN         NaN         NaN             NaN              NaN
# 12         NaN         NaN         NaN             NaN              NaN
# 13         NaN         NaN         NaN             NaN              NaN
# 14         NaN         NaN         NaN             NaN              NaN
# 15         NaN         NaN         NaN             NaN              NaN
# 16         NaN         NaN         NaN             NaN              NaN
# 17         NaN         NaN         NaN             NaN              NaN
# 18         NaN         NaN         NaN             NaN              NaN
# 19         NaN         NaN         NaN             NaN              NaN
# 20         NaN         NaN         NaN             NaN              NaN
# 21         NaN         NaN         NaN             NaN              NaN
# 22         NaN         NaN         NaN             NaN              NaN
# 23         NaN         NaN         NaN             NaN              NaN
# 24         NaN         NaN         NaN             NaN              NaN
# 25         NaN         NaN         NaN             NaN              NaN
# 26         NaN         NaN         NaN             NaN              NaN
# 27         NaN         NaN         NaN             NaN              NaN
# 28         NaN         NaN         NaN             NaN              NaN
# 29         NaN         NaN         NaN             NaN              NaN
# 30         NaN         NaN         NaN             NaN              NaN
# 31         NaN         NaN         NaN             NaN              NaN
# 32         NaN         NaN         NaN             NaN              NaN
# 33         NaN         NaN         NaN             NaN              NaN
# 34         NaN         NaN         NaN             NaN              NaN
# 35         NaN         NaN         NaN             NaN              NaN
# 36         NaN         NaN         NaN             NaN              NaN
# 37         NaN         NaN         NaN             NaN              NaN
# 38         NaN         NaN         NaN             NaN              NaN
# 39         NaN         NaN         NaN             NaN              NaN
# 40         NaN         NaN         NaN             NaN              NaN
# 41         NaN         NaN         NaN             NaN              NaN
# 42         NaN         NaN         NaN             NaN              NaN
# 43         NaN         NaN         NaN             NaN              NaN
# 44         NaN         NaN         NaN             NaN              NaN
#
#       Unnamed: 12   Unnamed: 13 Unnamed: 14    Unnamed: 15 Unnamed: 16  \
# 0   Valor Resgate   Valor Bruto        Imp.  Valor Líquido     % S/ RF
# 1             NaN           NaN         NaN            NaN         NaN
# 2             NaN           NaN         NaN            NaN         NaN
# 3            0.00  3,058,929.55        0.00   3,058,929.55      26.91%
# 4             NaN           NaN         NaN            NaN         NaN
# 5             NaN           NaN         NaN            NaN         NaN
# 6            0.00  5,310,063.36        0.00   5,310,063.36      46.72%
# 7            0.00  1,264,300.80        0.00   1,264,300.80      11.12%
# 8            0.00  1,264,300.80        0.00   1,264,300.80      11.12%
# 9             NaN           NaN         NaN            NaN         NaN
# 10            NaN           NaN         NaN            NaN         NaN
# 11            NaN           NaN         NaN            NaN         NaN
# 12            NaN           NaN         NaN            NaN         NaN
# 13            NaN           NaN         NaN            NaN         NaN
# 14            NaN           NaN         NaN            NaN         NaN
# 15            NaN           NaN         NaN            NaN         NaN
# 16            NaN           NaN         NaN            NaN         NaN
# 17            NaN           NaN         NaN            NaN         NaN
# 18            NaN           NaN         NaN            NaN         NaN
# 19            NaN           NaN         NaN            NaN         NaN
# 20            NaN           NaN         NaN            NaN         NaN
# 21            NaN           NaN         NaN            NaN         NaN
# 22            NaN           NaN         NaN            NaN         NaN
# 23            NaN           NaN         NaN            NaN         NaN
# 24            NaN           NaN         NaN            NaN         NaN
# 25            NaN           NaN         NaN            NaN         NaN
# 26            NaN           NaN         NaN            NaN         NaN
# 27            NaN           NaN         NaN            NaN         NaN
# 28            NaN           NaN         NaN            NaN         NaN
# 29            NaN           NaN         NaN            NaN         NaN
# 30            NaN           NaN         NaN            NaN         NaN
# 31            NaN           NaN         NaN            NaN         NaN
# 32            NaN           NaN         NaN            NaN         NaN
# 33            NaN           NaN         NaN            NaN         NaN
# 34            NaN           NaN         NaN            NaN         NaN
# 35            NaN           NaN         NaN            NaN         NaN
# 36            NaN           NaN         NaN            NaN         NaN
# 37            NaN           NaN         NaN            NaN         NaN
# 38            NaN           NaN         NaN            NaN         NaN
# 39            NaN           NaN         NaN            NaN         NaN
# 40            NaN           NaN         NaN            NaN         NaN
# 41            NaN           NaN         NaN            NaN         NaN
# 42            NaN           NaN         NaN            NaN         NaN
# 43            NaN           NaN         NaN            NaN         NaN
# 44            NaN           NaN         NaN            NaN         NaN
#
#    Unnamed: 17
# 0   % S/ Total
# 1          NaN
# 2          NaN
# 3        8.76%
# 4          NaN
# 5          NaN
# 6       15.20%
# 7        3.62%
# 8        3.62%
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN

# %%
df[5]
# Out:
#                      Contas a Pagar/Receber  \
# 0                    Contas a Pagar/Receber
# 1   Fatura de Empréstimo de Ações - Tomador
# 2   Fatura de Empréstimo de Ações - Tomador
# 3   Fatura de Empréstimo de Ações - Tomador
# 4   Fatura de Empréstimo de Ações - Tomador
# 5   Fatura de Empréstimo de Ações - Tomador
# 6   Fatura de Empréstimo de Ações - Tomador
# 7                                     Total
# 8                          Juros s/ Capital
# 9                          Juros s/ Capital
# 10                         Juros s/ Capital
# 11                         Juros s/ Capital
# 12                                    Total
# 13                        Pagamento de CBLC
# 14                        Pagamento de CBLC
# 15                                    Total
# 16                          Performance FEE
# 17                          Performance FEE
# 18                                    Total
# 19                 Performance FEE - Manual
# 20                 Performance FEE - Manual
# 21                                    Total
# 22               Performance FEE de resgate
# 23               Performance FEE de resgate
# 24               Performance FEE de resgate
# 25               Performance FEE de resgate
# 26               Performance FEE de resgate
# 27               Performance FEE de resgate
# 28               Performance FEE de resgate
# 29               Performance FEE de resgate
# 30               Performance FEE de resgate
# 31               Performance FEE de resgate
# 32               Performance FEE de resgate
# 33               Performance FEE de resgate
# 34               Performance FEE de resgate
# 35               Performance FEE de resgate
# 36               Performance FEE de resgate
# 37               Performance FEE de resgate
# 38               Performance FEE de resgate
# 39               Performance FEE de resgate
# 40               Performance FEE de resgate
# 41               Performance FEE de resgate
# 42               Performance FEE de resgate
# 43                                    Total
# 44                               Taxa ANBID
#
#                                            Unnamed: 0    Unnamed: 1  \
# 0                              Contas a Pagar/Receber         Valor
# 1   Fatura de Empr. de Ações Tomadora do papel [IV...       (26.55)
# 2   Fatura de Empr. de Ações Tomadora do papel [IV...       (34.26)
# 3   Fatura de Empr. de Ações Tomadora do papel [IV...       (77.38)
# 4   Fatura de Empr. de Ações Tomadora do papel [IV...        (3.81)
# 5   Fatura de Empr. de Ações Tomadora do papel [IV...       (79.86)
# 6   Fatura de Empr. de Ações Tomadora do papel [IV...       (55.70)
# 7                                            (310.51)         0.01%
# 8                                                 NaN           NaN
# 9   Receb. Juros s/ Cap. 0.03 de MGLU3 s/ 14,000 e...        368.23
# 10  Receb. Juros s/ Cap. 0.04 de WEGE3 s/ 4,000 em...        147.53
# 11  Receb. Juros s/ Cap. 0.10 de TOTS3 s/ 16,000 e...      1,600.00
# 12                                           2,115.76       (0.09)%
# 13                                                NaN           NaN
# 14  Despesa de Taxa de Custódia BM&F Bovespa com p...    (1,338.12)
# 15                                         (1,338.12)         0.06%
# 16                                                NaN           NaN
# 17                         Performance FEE Apropriada  (907,743.94)
# 18                                       (907,743.94)        39.16%
# 19                                                NaN           NaN
# 20                 Taxa de Performance - outubro/2020      (242.26)
# 21                                           (242.26)         0.01%
# 22                                                NaN           NaN
# 23  Performance Fee Proveniente de Resgate a Pagar...    (1,729.39)
# 24  Performance Fee Proveniente de Resgate a Pagar...       (55.48)
# 25  Performance Fee Proveniente de Resgate a Pagar...      (851.71)
# 26  Performance Fee Proveniente de Resgate a Pagar...      (916.85)
# 27  Performance Fee Proveniente de Resgate a Pagar...      (110.20)
# 28  Performance Fee Proveniente de Resgate a Pagar...    (1,924.52)
# 29  Performance Fee Proveniente de Resgate a Pagar...    (3,438.64)
# 30  Performance Fee Proveniente de Resgate a Pagar...       (89.27)
# 31  Performance Fee Proveniente de Resgate a Pagar...      (243.14)
# 32  Performance Fee Proveniente de Resgate a Pagar...    (3,604.42)
# 33  Performance FEE Bruta no resgate a Pagar em 01...    (8,182.99)
# 34  Performance Fee Proveniente de Resgate a Pagar...    (1,139.55)
# 35  Performance Fee Proveniente de Resgate a Pagar...      (254.67)
# 36  Performance Fee Proveniente de Resgate a Pagar...      (104.30)
# 37  Performance Fee Proveniente de Resgate a Pagar...      (344.36)
# 38  Performance Fee Proveniente de Resgate a Pagar...      (287.54)
# 39  Performance Fee Proveniente de Resgate a Pagar...      (458.02)
# 40  Performance Fee Proveniente de Resgate a Pagar...      (278.95)
# 41  Performance Fee Proveniente de Resgate a Pagar...      (106.61)
# 42  Performance Fee Proveniente de Resgate a Pagar...      (148.79)
# 43                                        (24,269.40)         1.05%
# 44                                                NaN           NaN
#
#         Unnamed: 2  Unnamed: 3
# 0   % S/ Total CPR  % S/ Total
# 1            0.00%     (0.00)%
# 2            0.00%     (0.00)%
# 3            0.00%     (0.00)%
# 4            0.00%     (0.00)%
# 5            0.00%     (0.00)%
# 6            0.00%     (0.00)%
# 7          (0.00)%         NaN
# 8              NaN         NaN
# 9          (0.02)%       0.00%
# 10         (0.01)%       0.00%
# 11         (0.07)%       0.00%
# 12           0.01%         NaN
# 13             NaN         NaN
# 14           0.06%     (0.00)%
# 15         (0.00)%         NaN
# 16             NaN         NaN
# 17          39.16%     (2.60)%
# 18         (2.60)%         NaN
# 19             NaN         NaN
# 20           0.01%     (0.00)%
# 21         (0.00)%         NaN
# 22             NaN         NaN
# 23           0.07%     (0.00)%
# 24           0.00%     (0.00)%
# 25           0.04%     (0.00)%
# 26           0.04%     (0.00)%
# 27           0.00%     (0.00)%
# 28           0.08%     (0.01)%
# 29           0.15%     (0.01)%
# 30           0.00%     (0.00)%
# 31           0.01%     (0.00)%
# 32           0.16%     (0.01)%
# 33           0.35%     (0.02)%
# 34           0.05%     (0.00)%
# 35           0.01%     (0.00)%
# 36           0.00%     (0.00)%
# 37           0.01%     (0.00)%
# 38           0.01%     (0.00)%
# 39           0.02%     (0.00)%
# 40           0.01%     (0.00)%
# 41           0.00%     (0.00)%
# 42           0.01%     (0.00)%
# 43         (0.07)%         NaN
# 44             NaN         NaN

# %%
df[6]
# Out:
#             Contas a Pagar/Receber  \
# 0           Contas a Pagar/Receber
# 1                       Taxa ANBID
# 2                            Total
# 3                       Taxa CETIP
# 4                       Taxa CETIP
# 5                            Total
# 6            Taxa de Administração
# 7            Taxa de Administração
# 8                            Total
# 9                 Taxa de Custódia
# 10                Taxa de Custódia
# 11                           Total
# 12  Taxa de Permanência de Futuros
# 13  Taxa de Permanência de Futuros
# 14  Taxa de Permanência de Futuros
# 15                           Total
# 16                      Taxa SELIC
# 17                      Taxa SELIC
# 18                           Total
# 19                             NaN
# 20                      Tesouraria
# 21                       Descrição
# 22             Saldo em Tesouraria
# 23                             NaN
# 24                   Rentabilidade
# 25                   Rentabilidade
# 26  Indexador Benchmark Rent. Real
# 27                    Cota líquida
# 28         CDI 3,257.6587% 0.2358%
# 29       IBOVESPA 24.3322% 0.2433%
# 30         IGP-M 561.2645% 0.1999%
# 31         PTAXV 505.5452% 0.1951%
#
#                                            Unnamed: 0        Unnamed: 1  \
# 0                              Contas a Pagar/Receber             Valor
# 1   Diferimento de despesa de ANBID - DIFERIMENTO ...            188.97
# 2                                                 NaN            188.97
# 3                                                 NaN               NaN
# 4             Despesa de CETIP com pagamento 08/01/21          (650.00)
# 5                                                 NaN          (650.00)
# 6                                                 NaN               NaN
# 7              Tx Administração a Pagar em 05/01/2021       (47,498.87)
# 8                                                 NaN       (47,498.87)
# 9                                                 NaN               NaN
# 10            Tx Custódia Bruta a Pagar em 08/01/2021        (2,052.00)
# 11                                                NaN        (2,052.00)
# 12                                                NaN               NaN
# 13  Taxa de Permanência do ativo FUT DI1 na corret...            (0.96)
# 14  Taxa de Permanência do ativo FUT WDO na corret...            (0.02)
# 15                                                NaN            (0.98)
# 16                                                NaN               NaN
# 17      Despesa de Custo Selic com pagamento 15/01/21           (39.84)
# 18                                                NaN           (39.84)
# 19                                        Total Geral    (2,318,239.34)
# 20                                                NaN               NaN
# 21                              Valor % S/ Tesouraria               NaN
# 22                                     193.85 100.00%               NaN
# 23                                     193.85 100.00%               NaN
# 24                                                NaN               NaN
# 25                                                NaN               NaN
# 26  Variação Diária Variação Mensal Variação Anual...  Últimos 24 Meses
# 27      0.2433220% 7.5887% 14.6972% 14.6972% 14.6972%          14.6972%
# 28         0.0074692% 0.1645% 0.6068% 0.6068% 0.6068%           0.6068%
# 29      0.0000000% 9.2971% 18.1648% 18.1648% 18.1648%          18.1648%
# 30      0.0433525% 1.0772% 11.8064% 11.8064% 11.8064%          11.8064%
# 31  0.0481306% (2.8545)% (3.3010)% (3.3010)% (3.30...         (3.3010)%
#
#         Unnamed: 2        Unnamed: 3
# 0   % S/ Total CPR        % S/ Total
# 1              NaN     (0.01)% 0.00%
# 2              NaN     (0.01)% 0.00%
# 3              NaN               NaN
# 4              NaN     0.03% (0.00)%
# 5              NaN     0.03% (0.00)%
# 6              NaN               NaN
# 7              NaN     2.05% (0.14)%
# 8              NaN     2.05% (0.14)%
# 9              NaN               NaN
# 10             NaN     0.09% (0.01)%
# 11             NaN     0.09% (0.01)%
# 12             NaN               NaN
# 13             NaN     0.00% (0.00)%
# 14             NaN     0.00% (0.00)%
# 15             NaN     0.00% (0.00)%
# 16             NaN               NaN
# 17             NaN     0.00% (0.00)%
# 18             NaN     0.00% (0.00)%
# 19             NaN   100.00% (6.64)%
# 20             NaN               NaN
# 21             NaN        % S/ Total
# 22             NaN             0.00%
# 23             NaN             0.00%
# 24             NaN               NaN
# 25             NaN               NaN
# 26             NaN  Últimos 36 Meses
# 27             NaN          14.6972%
# 28             NaN           0.6068%
# 29             NaN          18.1648%
# 30             NaN          11.8064%
# 31             NaN         (3.3010)%

# %%
df[7]
# Out:
#    Patrimônio           Unnamed: 0                          Unnamed: 1  \
# 0         NaN        Qtd. de Cotas  Valor da cota bruta de performance
# 1         NaN  30,453,393.32503018                                 NaN
#
#    Unnamed: 2             Unnamed: 3  Unnamed: 4     Unnamed: 5 Unnamed: 6
# 0         NaN  Valor da Cota Liquida         NaN     Patrimônio  Tipo Cota
# 1    1.176765                    NaN    1.146972  34,929,178.43          F

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-9a57fcc03444> in <module>
# ----> 1 df[8]
#
# IndexError: list index out of range
